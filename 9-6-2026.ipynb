# %% [markdown]
# ### Singly linked list problems:
# 1. reverse linked list(206)
# 2. linked list cycle(141)
# 3. Remove duplicates from sorted list(83)
#
# ### Stack
# 1. implementation using list
# 2. implementation using linked list
# 3. valid parenthesis
# 4. implement queue using stacks(232)
#
# ### Queue
# 1. implementation using list
# 2. implementation using linked list
# 3. Number of Students Unable to Eat Lunch

# %%
# stack implementation using list
class Stack:
    def __init__(self):
        self.stack = []
    def push(self,val):
        self.stack.append(val)
    def pop(self):
        if self.is_empty():
            return "stack is empty"
        return self.stack.pop()
    def is_empty(self):
        return not self.stack
    def display(self):
        for ele in self.stack:
            print(ele,end="==>")
        print()
    def size(self):
        return len(self.stack)
    def peek(self):
        if self.is_empty():
            return "stack is empty"
        return self.stack[-1]
        

s = Stack()
s.push(10)
s.push(20)
s.push(30)
s.display()
s.pop()
s.display()
print(s.is_empty())
# Out:
# 10==>20==>30==>
# 10==>20==>
# False

# %% [markdown]
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20240508162652/stack-as-linked-list.png">

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Stack:
    def __init__(self):
        self.top = None
    def push(self,val):
        new_node = Node(val)
        new_node.next = self.top
        self.top = new_node
    def pop(self):
        if self.is_empty():
            return "stack is empty"
        val = self.top.data
        self.top = self.top.next
        return val
    def is_empty(self):
        return not self.top
    def display(self):
        if self.is_empty():
            return "stack is empty"
        temp = self.top
        while temp:
            print(temp.data,end="==>")
            temp = temp.next
        print()
    def peek(self):
        if self.is_empty():
            return "stack is empty"
        return self.top.data
    def size(self):
        if self.is_empty():
            return "stack is empty"
        temp = self.top
        count = 0
        while temp:
            count += 1
            temp = temp.next
        return count

s = Stack()
print(s.is_empty())
s.push(10)
s.push(20)
s.push(30)
s.display()
s.pop()
s.display()
print(s.size())
# Out:
# True
# 30==>20==>10==>
# 20==>10==>
# 2

# %%
#Queue implementation using list
class Queue:
    def __init__(self):
        self.queue = []
    def enqueue(self,val):
        self.queue.append(val)
    def dequeue(self):
        if self.is_empty():
            return "Queue is empty"
        val = self.queue.pop(0)
        return val
    def display(self):
        print(self.queue)
    def is_empty(self):
        return len(self.queue) == 0
    def front(self):
        if self.is_empty():
            return "Queue is empty"
        return self.queue[0]
        
q = Queue()
q.enqueue(10)
q.enqueue(20)
q.enqueue(30)
q.enqueue(40)
q.display()
q.dequeue()
q.display()
# Out:
# [10, 20, 30, 40]
# [20, 30, 40]

# %% [markdown]
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20250325130840080788/Queue-Linked-List-Implementation_.webp">

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Queue:
    def __init__(self):
        self.front = None
        self.rear = None
    def enqueue(self,val):
        new_node = Node(val)
        if self.rear is None:
            self.rear = self.front = new_node
            return
        self.rear.next = new_node
        self.rear = new_node
    def dequeue(self):
        if self.front is None:
            return "Queue is empty"
        self.front = self.front.next
        if self.front is None:
            self.rear = None
        
    def is_empty(self):
        pass
