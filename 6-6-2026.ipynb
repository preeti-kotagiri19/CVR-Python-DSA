# %% [markdown]
# ### Two pointer approach
# ```
# 1. moving in opposite direction
#     167. Two Sum II
#     344. Reverse String
#
# 2. moving in same direction
#     75. sort colors
#     283. Move Zeroes
# ```
#
# ### prefix sum
#     303. Range Sum Query - Immutable
#
# ### Strings algorithms
#     palindrome check
#     Anagram check

# %% [markdown]
# ### Approach-1

# %%
from typing import List
class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        res = [0]*len(nums)
        j = 0
        for i in range(len(nums)):
            if nums[i] != 0:
                res[j] = nums[i]
                j += 1
        return res
                
obj = Solution()
obj.moveZeroes([0,1,0,3,12])
# Out:
# [1, 3, 12, 0, 0]

# %%
from typing import List
class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        j = 0
        for i in range(0,len(nums)):
            if nums[i] != 0:
                nums[j] = nums[i]
                j += 1
        for k in range(j,len(nums)):
            nums[k] = 0
        return nums
        
obj = Solution()
obj.moveZeroes([0,1,0,3,12])
# Out:
# [1, 3, 12, 0, 0]

# %%
from typing import List
class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        slow = 0
        for fast in range(0,len(nums)):
            if nums[fast] != 0:
                nums[slow],nums[fast] = nums[fast],nums[slow]
                slow += 1
        return nums
        
obj = Solution()
obj.moveZeroes([0,1,0,3,12])
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# ### 75. Sort Colors
# #### Aproach-1 using count()

# %%
class Solution:
    def sortColors(self, nums: List[int]) -> None:
        count_zeros = nums.count(0)
        count_ones = nums.count(1)
        count_twos = nums.count(2)
        nums[:] = ([0] * count_zeros) + ([1] * count_ones) + ([2] * count_twos)
        return nums
        
obj = Solution()
obj.sortColors([2,0,2,1,1,0])
# Out:
# [0, 0, 1, 1, 2, 2]

# %% [markdown]
# ### Approach-2 with two pointer

# %%
class Solution:
    def sortColors(self, nums: List[int]) -> None:
        left,mid,right = 0,0,len(nums)-1
        while mid <= right:
            if nums[mid] == 0:
                nums[left],nums[mid] = nums[mid],nums[left]
                left += 1
                mid += 1
            elif nums[mid] == 1:
                mid += 1
            else:
                nums[mid],nums[right] = nums[right],nums[mid]
                right -= 1
        return nums
        
obj = Solution()
obj.sortColors([2,0,2,1,1,0])
# Out:
# [0, 0, 1, 1, 2, 2]

# %% [markdown]
# ### 125. Valid Palindrome

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        res = ""
        s = s.lower()
        for ch in s:
            if ch.isalnum():
                res += ch
        return res == res[::-1]       
obj = Solution()
print(obj.isPalindrome("A man, a plan, a canal: Panama"))#True
print(obj.isPalindrome("race a car"))#False
print(obj.isPalindrome(" ")) #True
# Out:
# True
# False
# True

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        s = s.lower()
        res = "".join([ch for ch in s if ch.isalnum()])
        return res == res[::-1]       
obj = Solution()
print(obj.isPalindrome("A man, a plan, a canal: Panama"))#True
print(obj.isPalindrome("race a car"))#False
print(obj.isPalindrome(" ")) #True
# Out:
# True
# False
# True

# %%
from collections import Counter
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        return Counter(s) == Counter(t)
